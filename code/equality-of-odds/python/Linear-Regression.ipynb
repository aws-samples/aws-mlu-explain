# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(50)

# generate prices to be roughly $600 per square-foot
sqft = [220, 500, 550, 600, 750, 800, 900, 920, 1385, 1200, 1400, 1500, 1550, 1800, 2000]
prices = [np.round(i * np.random.normal(600, 200), 0) for i in sqft]

df = pd.DataFrame({'sqft': sqft, 'price': prices})

plt.ylim(0, 2000000)
sns.scatterplot(df.sqft, df.price)
# Out:
# /Users/wilberjw/opt/anaconda3/envs/py38/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sqft', ylabel='price'>

# %%
X = np.array(df.sqft).reshape(-1, 1)
y = np.array(df.price).reshape(-1, 1)
reg = LinearRegression().fit(X, y)

print('coef: ', reg.coef_[0][0])
print('intercept: ', reg.intercept_[0])

regline = [np.round(reg.coef_[0][0] *i + reg.intercept_[0], 0) for i in sqft]
df['regressionLine'] = regline
# Out:
# coef:  531.9087345372008
# intercept:  19166.672820966458

# %%
# reappend first row with correct values
newRow = {'sqft': [0], 'price': [19166.67], 'regressionLine': [19166.67]}
df_firstrow = pd.DataFrame(newRow)

# %%
data_df = pd.concat([df_firstrow, df], ignore_index = True)

# %%
# data_df.to_json('scatterData.json', orient='records')

# %%
# Generate data
x = df.sqft
y = df.price

# Initialize layout
fig, ax = plt.subplots(figsize = (9, 9))

# Add scatterplot
ax.scatter(x, y, s=60, alpha=0.7, edgecolors="k")

# Fit linear regression via least squares with numpy.polyfit
# It returns an slope (b) and intercept (a)
# deg=1 means linear fit (i.e. polynomial of degree 1)
b, a = np.polyfit(x**1, y, deg=1)
print('intercept: ', a)
print('slope: ', b)

# Create sequence of 100 numbers from 0 to 100 
xseq = np.linspace(0, 2000, num=100)

# Plot regression line
ax.plot(xseq, a + b * xseq, color="k", lw=2.5);
# Out:
# intercept:  19166.672820967062
# slope:  531.9087345372005

# %%
scatterData
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-14-ed2608a99b59> in <module>
# ----> 1 scatterData
#
# NameError: name 'scatterData' is not defined
